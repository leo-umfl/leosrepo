# %% [markdown]
# <a href="https://colab.research.google.com/github/leo-umfl/leosrepo/blob/main/bte320ENotes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
# Out:
# Hello

# %%
6/3
# Out:
# 2.0

# %%
6//4
# Out:
# 1

# %%
2*3
# Out:
# 6

# %%
7.0//2
# Out:
# 3.0

# %%
2**3
# Out:
# 8

# %%
5 % 3
# Out:
# 2

# %%
3%4
# Out:
# 3

# %%
3.14 * 3 ** 2
# Out:
# 28.26

# %%
3>5
# Out:
# False

# %%
4==4
# Out:
# True

# %%
4 !=5
# Out:
# True

# %%
s='abc'
