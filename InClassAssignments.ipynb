# %% [markdown]
# <a href="https://colab.research.google.com/github/leo-umfl/leosrepo/blob/main/InClassAssignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1st ICA

# %%
sales = float(input("Sales Amount: "))
tax = float(input("Tax Rate (%): "))
cogs = sales*.4
grossprofit = sales-cogs
taxes = grossprofit*(tax/100)
netincome = grossprofit-taxes

print(f"Sales: {sales:.2f}")
print(f"COGS: {cogs:.2f}")
print(f"Gross Profit: {grossprofit:.2f}")
print(f"Taxes: {taxes:.2f}")
print(f"Net Income: {netincome:.2f}")
# Out:
# Sales Amount: 12000
# Tax Rate (%): 30
# Sales: 12000.00
# COGS: 4800.00
# Gross Profit: 7200.00
# Taxes: 2160.00
# Net Income: 5040.00

# %% [markdown]
# 2nd ICA

# %%
D = float(input("Enter annual demand (units/year): "))
S = float(input("Enter ordering cost ($/order): "))
H = float(input("Enter holding cost ($/year/unit): "))

EOQ = ((2 * D * S) / H) ** 0.5
print(f"EOQ = {EOQ:.2f} units")
# Out:
# Enter annual demand (units/year): 4
# Enter ordering cost ($/order): 5
# Enter holding cost ($/year/unit): 6
# EOQ = 2.58 units

# %% [markdown]
# 3rd ICA

# %%
number1 = float(input("First Number: "))
operator = (input("Operator: "))
number2 = float(input("Second Number: "))

if operator == "+":
  res = number1+number2
elif operator == "-":
  res = number1-number2
elif operator == "*":
  res = number1*number2
elif operator == "/":
  res = number1/number2
elif operator == "//":
  res = number1//number2
elif operator == "**":
  res = number1**number2
elif operator == "%":
  res= number1%number2
else:
  print("invalid operation")

print(f"Result: {res}")
# Out:
# First Number: 6
# Operator: *
# Second Number: 7
# Result: 42.0

# %% [markdown]
# 4th ICA

# %%
print("Hours\tFee")

for hours in range(1,9):
  fee=5+2.5*hours
  if fee < 10:
    fee=10
  if fee > 20:
    fee=20
  print(hours,"\t$", f"{fee:.2f}")
# Out:
# Hours	Fee
# 1 	$ 10.00
# 2 	$ 10.00
# 3 	$ 12.50
# 4 	$ 15.00
# 5 	$ 17.50
# 6 	$ 20.00
# 7 	$ 20.00
# 8 	$ 20.00

# %% [markdown]
# 5th ICA

# %%
ticketPrice = 10
defaultAudience = 20

print(f"{"Ad$\tProfit"}")
for adMoney in range(0, 201, 25):
  revenue = (defaultAudience + 2 * adMoney ** 0.5)*ticketPrice
  costs = 200 + adMoney
  profit = revenue - costs
  print(f"{float(adMoney):.2f}\t{float(profit):.2f}")
# Out:
# Ad$	Profit
# 0.00	0.00
# 25.00	75.00
# 50.00	91.42
# 75.00	98.21
# 100.00	100.00
# 125.00	98.61
# 150.00	94.95
# 175.00	89.58
# 200.00	82.84

# %% [markdown]
# 6th ICA

# %%
import random

play = input("Do you want to play a game (y/n)? ")

while play == 'y':
  player = input("Choose b/w rock, paper, scissors: ").lower()
  computer = random.choice(['rock', 'paper', 'scissors'])

  if player == computer:
    print("Draw")
  elif player == "rock" and computer == "scissors":
    print("Player wins!")
  elif player == "scissors" and computer == "paper":
    print("Player wins!")
  elif player == "paper" and computer == "rock":
    print("Player wins!")
  else:
    print ("Computer wins")

  play = input("Do you want to continue (y/n)? ")
# Out:
# Do you want to play a game (y/n)? y
# Choose b/w rock, paper, scissors: paper
# Computer wins
# Do you want to continue (y/n)? y
# Choose b/w rock, paper, scissors: scissors
# Draw
# Do you want to continue (y/n)? y
# Choose b/w rock, paper, scissors: scissors
# Player wins!
# Do you want to continue (y/n)? n

# %% [markdown]
# 7th ICA

# %%
numbers = []

while True:
  num=int(input('Enter another number: '))
  if num == 0:
    break
  numbers.append(num)


numbers.sort(reverse=True)
print(numbers)
# Out:
# Enter another number: 6
# Enter another number: 7
# Enter another number: 8
# Enter another number: 8
# Enter another number: 0
# [8, 8, 7, 6]

# %% [markdown]
# 8th ICA

# %%
weights = [10.0, 9.9, 10.1, 10.05]

average = sum(weights) / len(weights)
print("Average=", average)

largest = max(weights)
print("Largest=", largest)
# Out:
# Average= 10.0125
# Largest= 10.1

# %% [markdown]
# 9th ICA

# %%
counts = {}
N = 5
i = 0

while i < N:
    name = input("Enter a name: ")
    if name not in counts:
        counts[name] = 1
    else:
        counts[name] += 1
    i += 1

print(counts)
# Out:
# Enter a name: bob
# Enter a name: john
# Enter a name: jill
# Enter a name: 2
# Enter a name: 4
# {'bob': 1, 'john': 1, 'jill': 1, '2': 1, '4': 1}

# %% [markdown]
# 10th ICA

# %%
products = {
    'P-01': 9.95,
    'P-02': 10.50
}

id=input('Enter Product ID: ')

if id in products:
  print(f"Price = {products[id]}$")
else:
  print(f"Product {id} does not exist, or is sold out.")
# Out:
# Enter Product ID: 4
# Product 4 does not exist, or is sold out.

# %% [markdown]
# 11th ICA

# %%
def calcFee(hours):
  fee=5+2.5*hours
  if fee<10:
    fee=10.0
  elif fee>20:
    fee=20.0
  print(fee)

def main():
  hours= int(input("Number of hours parked: "))
  calcFee(hours)

main()
# Out:
# Number of hours parked: 2
# 10.0

# %% [markdown]
# 12th ICA

# %%
def reverse(s):
    if len(s) == 0:
        return s
    return reverse(s[1:]) + s[0]

user_input = input("Enter a string: ")
print(reverse(user_input))
# Out:
# Enter a string: leo
# oel

# %% [markdown]
# 13th ICA

# %%
def roi(cost, revenue):
    if not isinstance(cost, (int, float)) or not isinstance(revenue, (int, float)):
        print("Error: inputs must be numeric")
        return
    if cost <= 0:
        print("Error: cost must be greater than 0")
        return
    return (revenue - cost) / cost

cost = float(input("Enter cost: "))
revenue = float(input("Enter revenue: "))
print(roi(cost, revenue))
# Out:
# Enter cost: 5
# Enter revenue: 10
# 1.0

# %% [markdown]
# 14th ICA

# %%
def loan_payment(principal, annual_rate, years):
    if principal <= 0 or annual_rate <= 0 or years <= 0:
        raise ValueError("All inputs must be positive numbers")
    r = annual_rate / 12
    n = years * 12
    payment = (r * principal) / (1 - (1 + r) ** -n)
    return payment

principal = float(input("Enter loan amount: "))
annual_rate = float(input("Enter annual interest rate (e.g. 0.05 for 5%): "))
years = float(input("Enter loan term in years: "))

print(f"Monthly payment: ${loan_payment(principal, annual_rate, years):.2f}")
# Out:
# Enter loan amount: 2
# Enter annual interest rate (e.g. 0.05 for 5%): .1
# Enter loan term in years: 10
# Monthly payment: $0.03

# %% [markdown]
# 15th ICA

# %%
def getValues(n):
  assert isinstance (n, int) and n>0, "n must be a positive integer"
  values = []
  for i in range(n):
    try:
      val = float(input("Enter value: "))
      values.append(val)
    except ValueError:
      print("Warning: Invalid Input. Please enter number")
  return values

def calcAverage(alist):
  assert isinstance(alist, list), "Input must be a list"
  if len(alist)<2:
    raise Exception("List must contain at least two values")
  included = alist[2:]
  return sum(included)/len(included)

try:
  n=int(input("How many values? "))
  values=getValues(n)
  print("Average:",calcAverage(values))
except ValueError:
  print("Warning: Numbers must be integers")
except Exception as e:
  print("Error:",e)
# Out:
# How many values? 3
# Enter value: 4
# Enter value: 4
# Enter value: 3
# Average: 3.0

# %% [markdown]
# 16th ICA

# %%
class Greeting:
    def __init__(self, first_name, last_name):
        self.first_name = first_name
        self.last_name = last_name

    def display(self, formal):
        if formal:
            print(f"{self.last_name}, {self.first_name}")
        else:
            print(self.first_name)

    def __str__(self):
        return "Class Greeting"


p = Greeting("Leo", "Spanier")
print(p)
p.display(formal=False)
p.display(formal=True)
# Out:
# Class Greeting
# Leo
# Spanier, Leo

# %% [markdown]
# 17th ICA

# %%
class Student:
  def __init__(self, name, number):
    self.__name=name
    self.number=number
    self.__courses=[]

  @property
  def name(self):
    return self.__name

  @name.setter
  def name(self,newName):
    self.name=name

  def get_courses(self):
    return self.__courses

  def __len__(self):
    return len(self.__courses)

  def enroll(self, newCourse):
    if newCourse not in self.__courses:
      self.__courses.append(newCourse)
    else:
      print(f"Student {self.__name} has already enrolled in {newCourse}.")

# %%
s = Student("John Doe",12345)
print(s.name)
print(s.get_courses)
s.enroll('BTE320')
print(len(s))
print(s.get_courses)
# Out:
# John Doe
# <bound method Student.get_courses of <__main__.Student object at 0x7c58abd00980>>
# 1
# <bound method Student.get_courses of <__main__.Student object at 0x7c58abd00980>>

# %% [markdown]
# 18th ICA

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def distance(self, other):
        dx=(self.x-other.x)**2
        dy=(self.y-other.y)**2
        return (dx+dy)**0.5

class Rectangle:
    def __init__(self):
        self.p1 = Point(0,0)
        self.p2 = Point(3,0)
        self.p3 = Point(0,3)
        self.p4 = Point(3,3)

        self.width = self.p1.distance(self.p2)
        self.height = self.p1.distance(self.p3)

    def area(self):
        return self.width * self.height

# %%
z=Rectangle()
z.area()
# Out:
# 9.0

# %% [markdown]
# 19th ICA

# %%
class Employee:
  def __init__(self,name,wage,hours):
    self.name=name
    self.__hourly_wage=wage
    self.hours=hours

  def get_wage(self):
    return self.__hourly_wage

  def set_wage(self,newWage):
    if newWage<=0:
      print("Negative wage values not allowed.")
    else:
     self.__hourly_wage=newWage

  def calculate_pay(self):
    return self.__hourly_wage*self.hours

  def __str__(self):
    return f"Employee: {self.name}\nHourly wages: {self.__hourly_wage}$/hour"

class Manager(Employee):
  def __init__(self,name,wage,hours,bonus):
    super().__init__(name,wage,hours)
    self.bonus=bonus

  def calculate_pay(self):
    return (1+self.bonus)*self.get_wage()*self.hours

employee=Employee("Bob",50,10)
manager=Manager("Alice",100,15,.2)
print(employee)
print(manager)
print(f"Employee {employee.name} weekly salary is: {employee.calculate_pay()}$")
print(f"Manager {manager.name} weekly salary is: {manager.calculate_pay()}$ that includes a {manager.bonus *100}% bonus")
# Out:
# Employee: Bob
# Hourly wages: 50$/hour
# Employee: Alice
# Hourly wages: 100$/hour
# Employee Bob weekly salary is: 500$
# Manager Alice weekly salary is: 1800.0$ that includes a 20.0% bonus
